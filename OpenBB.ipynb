# %% [markdown]
# <a href="https://colab.research.google.com/github/mmistroni/jupyter/blob/master/OpenBB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### OpenBB Notebook

# %%
# !pip install "openbb[all]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 26.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 KB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.8/507.8 KB 28.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 KB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.1/81.1 KB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 41.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 52.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.8/137.8 KB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 KB 4.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %% [markdown]
# #### Documentation: pip install "openbb[all]"

# %%
# !pip install -U prompt-toolkit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from openbb_terminal.sdk import openbb
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-8bc494101e40> in <module>
# ----> 1 from openbb_terminal.sdk import openbb
#
# /usr/local/lib/python3.9/dist-packages/openbb_terminal/sdk.py in <module>
#      12
#      13 from openbb_terminal.cryptocurrency.due_diligence.pycoingecko_model import Coin
# ---> 14 from openbb_terminal.dashboards.dashboards_controller import DashboardsController
#      15 from openbb_terminal.helper_classes import TerminalStyle  # noqa: F401
#      16 from openbb_terminal.reports import widget_helpers as widgets  # noqa: F401
#
# /usr/local/lib/python3.9/dist-packages/openbb_terminal/dashboards/dashboards_controller.py in <module>
#      10 import openbb_terminal.config_terminal as cfg
#      11 from openbb_terminal import feature_flags as obbff
# ---> 12 from openbb_terminal.custom_prompt_toolkit import NestedCompleter
# ...
