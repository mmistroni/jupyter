# %% [markdown]
# <a href="https://colab.research.google.com/github/mmistroni/jupyter/blob/master/OpenBB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### OpenBB Notebook

# %%
import sys
sys.path.append("/usr/local/lib/python3.9/site-packages")
# !pip install "openbb"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: openbb in /usr/local/lib/python3.9/dist-packages (2.5.1)
# Requirement already satisfied: robin-stocks<3.0.0,>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.1.0)
# Requirement already satisfied: numpy==1.23.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.23.4)
# Requirement already satisfied: prompt-toolkit<4.0.0,>=3.0.16 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.0.38)
# Requirement already satisfied: tenacity<8.0.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (7.0.0)
# Requirement already satisfied: rich<13.0.0,>=12.6.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (12.6.0)
# Requirement already satisfied: yahooquery<3.0.0,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.3.0)
# Requirement already satisfied: python-dotenv<0.20.0,>=0.19.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.19.2)
# Requirement already satisfied: ipython==8.5.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (8.5.0)
# Requirement already satisfied: protobuf==3.20.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.20.1)
# Requirement already satisfied: rapidfuzz<3.0.0,>=2.13.7 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.13.7)
# Requirement already satisfied: yfinance<0.3.0,>=0.2.9 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.2.12)
# Requirement already satisfied: ruamel.yaml<0.18.0,>=0.17.21 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.17.21)
# Requirement already satisfied: FundamentalAnalysis<0.3.0,>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.2.14)
# Requirement already satisfied: financedatabase<3.0.0,>=2.0.8 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.0.9)
# Requirement already satisfied: ipywidgets<9.0.0,>=8.0.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (8.0.4)
# Requirement already satisfied: finviz!=1.4.5,<2.0.0,>=1.3.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.4.4)
# Requirement already satisfied: finvizfinance<0.15.0,>=0.14.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.14.5)
# Requirement already satisfied: ccxt<3.0.0,>=2.5.67 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.9.16)
# Requirement already satisfied: ascii-magic<2.0,>=1.6 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.6)
# Requirement already satisfied: pycoingecko<3.0.0,>=2.2.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.3.0)
# Requirement already satisfied: tokenterminal<2.0.0,>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.0.1)
# Requirement already satisfied: praw<8.0.0,>=7.1.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (7.7.0)
# Requirement already satisfied: setuptools<65.5.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (63.4.3)
# Requirement already satisfied: alpha-vantage<3.0.0,>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.3.1)
# Requirement already satisfied: dnspython<3.0.0,>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.3.0)
# Requirement already satisfied: linearmodels<5.0,>=4.25 in /usr/local/lib/python3.9/dist-packages (from openbb) (4.27)
# Requirement already satisfied: pandas-ta<0.4.0,>=0.3.14-beta.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.3.14b0)
# Requirement already satisfied: detecta<0.0.6,>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.0.5)
# Requirement already satisfied: streamlit<2.0.0,>=1.17.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.20.0)
# Requirement already satisfied: tweepy<5.0.0,>=4.12.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (4.13.0)
# Requirement already satisfied: papermill==2.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.4.0)
# Requirement already satisfied: degiro-connector<3.0.0,>=2.0.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.0.21)
# Requirement already satisfied: jupyterlab<4.0.0,>=3.2.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.6.1)
# Requirement already satisfied: bt<0.3.0,>=0.2.9 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.2.9)
# Requirement already satisfied: psaw<0.0.13,>=0.0.12 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.0.12)
# Requirement already satisfied: holidays<0.15.0,>=0.14.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.14.2)
# Requirement already satisfied: mplfinance<0.13.0,>=0.12.7-alpha.7 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.12.9b7)
# Requirement already satisfied: screeninfo<0.7.0,>=0.6.7 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.6.7)
# Requirement already satisfied: Pygments<3.0.0,>=2.11.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.14.0)
# Requirement already satisfied: pyally<2.0.0,>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.1.2)
# Requirement already satisfied: bs4<0.0.2,>=0.0.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.25.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.28.2)
# Requirement already satisfied: valinvest<0.0.3,>=0.0.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.0.2)
# Requirement already satisfied: pythclient<0.2.0,>=0.1.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.1.4)
# Requirement already satisfied: html5lib<2.0,>=1.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.1)
# Requirement already satisfied: GitPython<4.0.0,>=3.1.17 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.1.31)
# Requirement already satisfied: pandas<2.0.0,>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.5.3)
# Requirement already satisfied: packaging>=22.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (23.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.5 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.10.6)
# Requirement already satisfied: Jinja2<4.0.0,>=3.0.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.1.2)
# Requirement already satisfied: y-py!=0.5.5 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.5.9)
# Requirement already satisfied: scipy<2.0.0,>=1.9.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.10.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.51.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.51.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (5.5.0)
# Requirement already satisfied: python-i18n<0.4.0,>=0.3.9 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.3.9)
# Requirement already satisfied: mstarpy<0.0.5,>=0.0.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.0.4)
# Requirement already satisfied: seaborn<0.12.0,>=0.11.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.11.2)
# Requirement already satisfied: voila>=0.3.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.4.0)
# Requirement already satisfied: stocksera<0.2.0,>=0.1.21 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.1.21)
# Requirement already satisfied: matplotlib<4.0.0,>=3.3.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.7.1)
# Requirement already satisfied: pyrsistent<0.19.0,>=0.18.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.18.1)
# Requirement already satisfied: fredapi<0.5.0,>=0.4.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.4.3)
# Requirement already satisfied: fred<4.0,>=3.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.1)
# Requirement already satisfied: intrinio-sdk<7.0.0,>=6.22.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (6.22.2)
# Requirement already satisfied: openpyxl<4.0.0,>=3.0.9 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.0.10)
# Requirement already satisfied: ipympl<0.9.0,>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.8.4)
# Requirement already satisfied: feedparser<7.0.0,>=6.0.10 in /usr/local/lib/python3.9/dist-packages (from openbb) (6.0.10)
# Requirement already satisfied: ipyflex<0.3.0,>=0.2.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.2.6)
# Requirement already satisfied: sparqlwrapper<3.0.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.0.0)
# Requirement already satisfied: charset-normalizer==2.1.1 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.1.1)
# Requirement already satisfied: python-binance<2.0.0,>=1.0.15 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.0.17)
# Requirement already satisfied: tradingview-ta<4.0.0,>=3.2.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.3.0)
# Requirement already satisfied: jupyterlab-widgets<4.0.0,>=3.0.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.0.5)
# Requirement already satisfied: Quandl<4.0.0,>=3.6.0 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.7.0)
# Requirement already satisfied: pytrends<5.0.0,>=4.7.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (4.9.0)
# Requirement already satisfied: psutil!=5.9.4 in /usr/local/lib/python3.9/dist-packages (from openbb) (5.4.8)
# Requirement already satisfied: python-coinmarketcap<0.3,>=0.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.2)
# Requirement already satisfied: iso8601<0.2.0,>=0.1.14 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.1.16)
# Requirement already satisfied: finnhub-python<3.0.0,>=2.4.10 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.4.16)
# Requirement already satisfied: oandapyV20<0.7.0,>=0.6.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.6.3)
# Requirement already satisfied: pandas-market-calendars<3.3,>=3.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.2)
# Requirement already satisfied: watchdog<3.0.0,>=2.1.9 in /usr/local/lib/python3.9/dist-packages (from openbb) (2.3.1)
# Requirement already satisfied: squarify<0.5.0,>=0.4.3 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.4.3)
# Requirement already satisfied: statsmodels<0.14,>=0.13 in /usr/local/lib/python3.9/dist-packages (from openbb) (0.13.5)
# Requirement already satisfied: vaderSentiment==3.3.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (3.3.2)
# Requirement already satisfied: thepassiveinvestor<2.0.0,>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from openbb) (1.1.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (4.4.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (4.8.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (5.7.1)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (0.1.6)
# Requirement already satisfied: stack-data in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (0.6.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.9/dist-packages (from ipython==8.5.0->openbb) (0.18.2)
# Requirement already satisfied: nbformat>=5.1.2 in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (5.7.3)
# Requirement already satisfied: tqdm>=4.32.2 in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (4.65.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (6.0)
# Requirement already satisfied: ansiwrap in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (0.8.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (0.4)
# Requirement already satisfied: nbclient>=0.2.0 in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (0.7.2)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from papermill==2.4->openbb) (8.1.3)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/dist-packages (from alpha-vantage<3.0.0,>=2.3.1->openbb) (3.8.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.9/dist-packages (from ascii-magic<2.0,>=1.6->openbb) (8.4.0)
# Requirement already satisfied: colorama in /usr/local/lib/python3.9/dist-packages (from ascii-magic<2.0,>=1.6->openbb) (0.4.6)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from bs4<0.0.2,>=0.0.1->openbb) (4.11.2)
# Requirement already satisfied: ffn>=0.3.5 in /usr/local/lib/python3.9/dist-packages (from bt<0.3.0,>=0.2.9->openbb) (0.3.6)
# Requirement already satisfied: pyprind>=2.11 in /usr/local/lib/python3.9/dist-packages (from bt<0.3.0,>=0.2.9->openbb) (2.11.3)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.9/dist-packages (from ccxt<3.0.0,>=2.5.67->openbb) (2022.12.7)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.9/dist-packages (from ccxt<3.0.0,>=2.5.67->openbb) (39.0.2)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.9/dist-packages (from ccxt<3.0.0,>=2.5.67->openbb) (1.8.2)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from ccxt<3.0.0,>=2.5.67->openbb) (3.0.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.12.1 in /usr/local/lib/python3.9/dist-packages (from degiro-connector<3.0.0,>=2.0.3->openbb) (1.15.0)
# Requirement already satisfied: onetimepass<2.0.0,>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from degiro-connector<3.0.0,>=2.0.3->openbb) (1.0.1)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.9/dist-packages (from feedparser<7.0.0,>=6.0.10->openbb) (1.0.0)
# Requirement already satisfied: user-agent in /usr/local/lib/python3.9/dist-packages (from finviz!=1.4.5,<2.0.0,>=1.3.4->openbb) (0.1.10)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.9/dist-packages (from finviz!=1.4.5,<2.0.0,>=1.3.4->openbb) (1.26.15)
# Requirement already satisfied: cssselect in /usr/local/lib/python3.9/dist-packages (from finviz!=1.4.5,<2.0.0,>=1.3.4->openbb) (1.2.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from finviz!=1.4.5,<2.0.0,>=1.3.4->openbb) (4.9.2)
# Requirement already satisfied: datetime in /usr/local/lib/python3.9/dist-packages (from finvizfinance<0.15.0,>=0.14.0->openbb) (5.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.9/dist-packages (from GitPython<4.0.0,>=3.1.17->openbb) (4.0.10)
# Requirement already satisfied: convertdate>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.4.0)
# Requirement already satisfied: korean-lunar-calendar in /usr/local/lib/python3.9/dist-packages (from holidays<0.15.0,>=0.14.2->openbb) (0.3.1)
# Requirement already satisfied: hijri-converter in /usr/local/lib/python3.9/dist-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.2.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.9/dist-packages (from holidays<0.15.0,>=0.14.2->openbb) (2.8.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.9/dist-packages (from html5lib<2.0,>=1.1->openbb) (0.5.1)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.9/dist-packages (from html5lib<2.0,>=1.1->openbb) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.9/dist-packages (from intrinio-sdk<7.0.0,>=6.22.2->openbb) (1.3.4)
# Requirement already satisfied: ipykernel>=4.7 in /usr/local/lib/python3.9/dist-packages (from ipympl<0.9.0,>=0.8.2->openbb) (5.3.4)
# Requirement already satisfied: widgetsnbextension~=4.0 in /usr/local/lib/python3.9/dist-packages (from ipywidgets<9.0.0,>=8.0.2->openbb) (4.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from Jinja2<4.0.0,>=3.0.3->openbb) (2.1.2)
# Requirement already satisfied: jupyter-server-ydoc<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (0.6.1)
# Requirement already satisfied: jupyterlab-server~=2.19 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (2.20.0)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (6.2)
# Requirement already satisfied: jupyter-ydoc~=0.2.2 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (0.2.3)
# Requirement already satisfied: notebook<7 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (6.3.0)
# Requirement already satisfied: nbclassic in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (0.5.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (5.2.0)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (1.23.6)
# Requirement already satisfied: tomli in /usr/local/lib/python3.9/dist-packages (from jupyterlab<4.0.0,>=3.2.4->openbb) (2.0.1)
# Requirement already satisfied: Cython>=0.29.21 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (0.29.33)
# Requirement already satisfied: pyhdfe>=0.1 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (0.1.2)
# Requirement already satisfied: mypy-extensions>=0.4 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (1.0.0)
# Requirement already satisfied: formulaic~=0.3.2 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (0.3.4)
# Requirement already satisfied: setuptools-scm<7.0.0,>=6.4.2 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (6.4.2)
# Requirement already satisfied: property-cached>=1.6.3 in /usr/local/lib/python3.9/dist-packages (from linearmodels<5.0,>=4.25->openbb) (1.6.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (1.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (0.11.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib<4.0.0,>=3.3.3->openbb) (4.39.0)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.9/dist-packages (from openpyxl<4.0.0,>=3.0.9->openbb) (1.1.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas<2.0.0,>=1.5.0->openbb) (2022.7.1)
# Requirement already satisfied: exchange-calendars>=3.3 in /usr/local/lib/python3.9/dist-packages (from pandas-market-calendars<3.3,>=3.2->openbb) (4.2.5)
# Requirement already satisfied: websocket-client>=0.54.0 in /usr/local/lib/python3.9/dist-packages (from praw<8.0.0,>=7.1.4->openbb) (1.5.1)
# Requirement already satisfied: prawcore<3,>=2.1 in /usr/local/lib/python3.9/dist-packages (from praw<8.0.0,>=7.1.4->openbb) (2.3.0)
# Requirement already satisfied: update-checker>=0.18 in /usr/local/lib/python3.9/dist-packages (from praw<8.0.0,>=7.1.4->openbb) (0.18.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.9/dist-packages (from prompt-toolkit<4.0.0,>=3.0.16->openbb) (0.2.6)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.9/dist-packages (from pyally<2.0.0,>=1.1.2->openbb) (1.3.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/dist-packages (from pydantic<2.0.0,>=1.10.5->openbb) (4.5.0)
# Requirement already satisfied: loguru in /usr/local/lib/python3.9/dist-packages (from pythclient<0.2.0,>=0.1.2->openbb) (0.6.0)
# Requirement already satisfied: base58 in /usr/local/lib/python3.9/dist-packages (from pythclient<0.2.0,>=0.1.2->openbb) (2.1.1)
# Requirement already satisfied: backoff in /usr/local/lib/python3.9/dist-packages (from pythclient<0.2.0,>=0.1.2->openbb) (2.2.1)
# Requirement already satisfied: flake8 in /usr/local/lib/python3.9/dist-packages (from pythclient<0.2.0,>=0.1.2->openbb) (6.0.0)
# Requirement already satisfied: ujson in /usr/local/lib/python3.9/dist-packages (from python-binance<2.0.0,>=1.0.15->openbb) (5.7.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.9/dist-packages (from python-binance<2.0.0,>=1.0.15->openbb) (3.17)
# Requirement already satisfied: dateparser in /usr/local/lib/python3.9/dist-packages (from python-binance<2.0.0,>=1.0.15->openbb) (1.1.7)
# Requirement already satisfied: websockets in /usr/local/lib/python3.9/dist-packages (from python-binance<2.0.0,>=1.0.15->openbb) (10.4)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from Quandl<4.0.0,>=3.6.0->openbb) (9.1.0)
# Requirement already satisfied: inflection>=0.3.1 in /usr/local/lib/python3.9/dist-packages (from Quandl<4.0.0,>=3.6.0->openbb) (0.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0,>=2.25.1->openbb) (2.10)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from rich<13.0.0,>=12.6.0->openbb) (0.9.1)
# Requirement already satisfied: pyotp in /usr/local/lib/python3.9/dist-packages (from robin-stocks<3.0.0,>=2.0.3->openbb) (2.8.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from ruamel.yaml<0.18.0,>=0.17.21->openbb) (0.2.7)
# Requirement already satisfied: rdflib>=6.1.1 in /usr/local/lib/python3.9/dist-packages (from sparqlwrapper<3.0.0,>=2.0.0->openbb) (6.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.9/dist-packages (from statsmodels<0.14,>=0.13->openbb) (0.5.3)
# Requirement already satisfied: pympler>=0.9 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (1.0.1)
# Requirement already satisfied: pydeck>=0.1.dev5 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (0.8.0)
# Requirement already satisfied: cachetools>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (5.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (0.10.2)
# Requirement already satisfied: validators>=0.2 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (0.20.0)
# Requirement already satisfied: semver in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (2.13.0)
# Requirement already satisfied: blinker>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (1.5)
# Requirement already satisfied: tzlocal>=1.1 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (4.2)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (6.0.0)
# Requirement already satisfied: pyarrow>=4.0 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (9.0.0)
# Requirement already satisfied: altair<5,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from streamlit<2.0.0,>=1.17.0->openbb) (4.2.2)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from tweepy<5.0.0,>=4.12.1->openbb) (3.2.2)
# Requirement already satisfied: jupyter-client<=7.4.1,>=6.1.3 in /usr/local/lib/python3.9/dist-packages (from voila>=0.3.0->openbb) (6.1.12)
# Requirement already satisfied: nbconvert<8,>=6.4.5 in /usr/local/lib/python3.9/dist-packages (from voila>=0.3.0->openbb) (6.5.4)
# Requirement already satisfied: requests-futures>=1.0.0 in /usr/local/lib/python3.9/dist-packages (from yahooquery<3.0.0,>=2.3.0->openbb) (1.0.0)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.9/dist-packages (from yfinance<0.3.0,>=0.2.9->openbb) (1.4.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.9/dist-packages (from yfinance<0.3.0,>=0.2.9->openbb) (0.0.11)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.9/dist-packages (from yfinance<0.3.0,>=0.2.9->openbb) (2.3.5)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from aiodns>=1.1.1->ccxt<3.0.0,>=2.5.67->openbb) (4.3.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.9/dist-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.9/dist-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (22.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/dist-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (6.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from aiohttp->alpha-vantage<3.0.0,>=2.3.1->openbb) (1.3.3)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (4.17.3)
# Requirement already satisfied: toolz in /usr/local/lib/python3.9/dist-packages (from altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (0.12.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->bs4<0.0.2,>=0.0.1->openbb) (2.4)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /usr/local/lib/python3.9/dist-packages (from convertdate>=2.3.0->holidays<0.15.0,>=0.14.2->openbb) (0.5.12)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/dist-packages (from cryptography>=2.6.1->ccxt<3.0.0,>=2.5.67->openbb) (1.15.1)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.9/dist-packages (from exchange-calendars>=3.3->pandas-market-calendars<3.3,>=3.2->openbb) (2.2.0)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.9/dist-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.10.0)
# Requirement already satisfied: scikit-learn>=0.15 in /usr/local/lib/python3.9/dist-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (1.2.2)
# Requirement already satisfied: future>=0.15 in /usr/local/lib/python3.9/dist-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.16.0)
# Requirement already satisfied: tabulate>=0.7.5 in /usr/local/lib/python3.9/dist-packages (from ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (0.8.10)
# Requirement already satisfied: interface-meta<2.0.0,>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from formulaic~=0.3.2->linearmodels<5.0,>=4.25->openbb) (1.3.0)
# Requirement already satisfied: astor>=0.8 in /usr/local/lib/python3.9/dist-packages (from formulaic~=0.3.2->linearmodels<5.0,>=4.25->openbb) (0.8.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from gitdb<5,>=4.0.1->GitPython<4.0.0,>=3.1.17->openbb) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=1.4->streamlit<2.0.0,>=1.17.0->openbb) (3.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.9/dist-packages (from jedi>=0.16->ipython==8.5.0->openbb) (0.8.3)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.9/dist-packages (from jupyter-client<=7.4.1,>=6.1.3->voila>=0.3.0->openbb) (23.2.1)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.9/dist-packages (from jupyter-core->jupyterlab<4.0.0,>=3.2.4->openbb) (3.1.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (3.6.2)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.9/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (21.3.0)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.9/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (1.8.0)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.9/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.16.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.9/dist-packages (from jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.17.1)
# Requirement already satisfied: jupyter-server-fileid<1,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.8.0)
# Requirement already satisfied: ypy-websocket<0.9.0,>=0.8.2 in /usr/local/lib/python3.9/dist-packages (from jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.8.2)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.9/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.2.4->openbb) (2.12.1)
# Requirement already satisfied: json5>=0.9.0 in /usr/local/lib/python3.9/dist-packages (from jupyterlab-server~=2.19->jupyterlab<4.0.0,>=3.2.4->openbb) (0.9.11)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (0.2.2)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (1.2.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (1.5.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (0.7.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.9/dist-packages (from nbconvert<8,>=6.4.5->voila>=0.3.0->openbb) (6.0.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.9/dist-packages (from nbformat>=5.1.2->papermill==2.4->openbb) (2.16.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.9/dist-packages (from notebook<7->jupyterlab<4.0.0,>=3.2.4->openbb) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.9/dist-packages (from pexpect>4.3->ipython==8.5.0->openbb) (0.7.0)
# Requirement already satisfied: isodate in /usr/local/lib/python3.9/dist-packages (from rdflib>=6.1.1->sparqlwrapper<3.0.0,>=2.0.0->openbb) (0.6.1)
# Requirement already satisfied: pytz-deprecation-shim in /usr/local/lib/python3.9/dist-packages (from tzlocal>=1.1->streamlit<2.0.0,>=1.17.0->openbb) (0.1.0.post0)
# Requirement already satisfied: textwrap3>=0.9.2 in /usr/local/lib/python3.9/dist-packages (from ansiwrap->papermill==2.4->openbb) (0.9.2)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /usr/local/lib/python3.9/dist-packages (from dateparser->python-binance<2.0.0,>=1.0.15->openbb) (2022.6.2)
# Requirement already satisfied: zope.interface in /usr/local/lib/python3.9/dist-packages (from datetime->finvizfinance<0.15.0,>=0.14.0->openbb) (5.5.2)
# Requirement already satisfied: pycodestyle<2.11.0,>=2.10.0 in /usr/local/lib/python3.9/dist-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (2.10.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.9/dist-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (0.7.0)
# Requirement already satisfied: pyflakes<3.1.0,>=3.0.0 in /usr/local/lib/python3.9/dist-packages (from flake8->pythclient<0.2.0,>=0.1.2->openbb) (3.0.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from nbclassic->jupyterlab<4.0.0,>=3.2.4->openbb) (0.2.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.9/dist-packages (from nbclassic->jupyterlab<4.0.0,>=3.2.4->openbb) (1.5.6)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.9/dist-packages (from stack-data->ipython==8.5.0->openbb) (2.2.1)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.9/dist-packages (from stack-data->ipython==8.5.0->openbb) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.9/dist-packages (from stack-data->ipython==8.5.0->openbb) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.9/dist-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (1.3.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<3.0.0,>=2.5.67->openbb) (2.21)
# Requirement already satisfied: jupyter-events>=0.5.0 in /usr/local/lib/python3.9/dist-packages (from jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.6.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.15->ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.15->ffn>=0.3.5->bt<0.3.0,>=0.2.9->openbb) (1.1.1)
# Requirement already satisfied: aiofiles<23,>=22.1.0 in /usr/local/lib/python3.9/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (22.1.0)
# Requirement already satisfied: aiosqlite<1,>=0.17.0 in /usr/local/lib/python3.9/dist-packages (from ypy-websocket<0.9.0,>=0.8.2->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.18.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.9/dist-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab<4.0.0,>=3.2.4->openbb) (21.2.0)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.9/dist-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit<2.0.0,>=1.17.0->openbb) (2022.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.9/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.9/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.9/dist-packages (from jupyter-events>=0.5.0->jupyter-server-fileid<1,>=0.6.0->jupyter-server-ydoc<0.7.0,>=0.6.0->jupyterlab<4.0.0,>=3.2.4->openbb) (0.1.1)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (1.2.0)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (1.5.1)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (2.3)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (20.11.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.9/dist-packages (from jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (1.12)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from isoduration->jsonschema>=3.0->altair<5,>=3.2.0->streamlit<2.0.0,>=1.17.0->openbb) (1.2.3)

# %% [markdown]
# #### Documentation: pip install "openbb[all]"

# %%
pip install torch==1.12.1+cu116 torchvision==0.13.1+cu116 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/, https://download.pytorch.org/whl/cu116
# Collecting torch==1.12.1+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.12.1%2Bcu116-cp39-cp39-linux_x86_64.whl (1904.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 GB 632.5 kB/s eta 0:00:00
# Collecting torchvision==0.13.1+cu116
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.13.1%2Bcu116-cp39-cp39-linux_x86_64.whl (23.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.5/23.5 MB 42.6 MB/s eta 0:00:00
# Collecting torchaudio==0.12.1
#   Downloading https://download.pytorch.org/whl/cu116/torchaudio-0.12.1%2Bcu116-cp39-cp39-linux_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 45.5 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch==1.12.1+cu116) (4.5.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision==0.13.1+cu116) (1.23.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision==0.13.1+cu116) (2.28.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision==0.13.1+cu116) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.13.1+cu116) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.13.1+cu116) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.13.1+cu116) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision==0.13.1+cu116) (2.10)
# Installing collected packages: torch, torchvision, torchaudio
#   Attempting uninstall: torch
#     Found existing installation: torch 1.11.0
#     Uninstalling torch-1.11.0:
#       Successfully uninstalled torch-1.11.0
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.14.1+cu116
#     Uninstalling torchvision-0.14.1+cu116:
#       Successfully uninstalled torchvision-0.14.1+cu116
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 0.13.1+cu116
#     Uninstalling torchaudio-0.13.1+cu116:
#       Successfully uninstalled torchaudio-0.13.1+cu116
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchtext 0.14.1 requires torch==1.13.1, but you have torch 1.12.1+cu116 which is incompatible.
# Successfully installed torch-1.12.1+cu116 torchaudio-0.12.1+cu116 torchvision-0.13.1+cu116

# %%
from openbb_terminal.sdk import openbb
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 from openbb_terminal.sdk import openbb
#
# File /usr/local/lib/python3.9/dist-packages/openbb_terminal/sdk.py:19
#      16 from openbb_terminal.reports import widget_helpers as widgets  # noqa: F401
#      17 from openbb_terminal.reports.reports_controller import ReportController
# ---> 19 import openbb_terminal.core.sdk.sdk_init as lib
#      20 from openbb_terminal.core.sdk import (
#      21     controllers as ctrl,
#      22     models as model,
#      23 )
#      24 from openbb_terminal import feature_flags as obbff
#
# File /usr/local/lib/python3.9/dist-packages/openbb_terminal/core/sdk/sdk_init.py:427
#     424     from darts import utils
#     426     FORECASTING_TOOLKIT_ENABLED = True
# --> 427     from openbb_terminal.forecast import (
#     428         anom_model as forecast_anom_model,
#     429         anom_view as forecast_anom_view,
#     430         autoarima_model as forecast_autoarima_model,
#     431         autoarima_view as forecast_autoarima_view,
#     432         autoces_model as forecast_autoces_model,
#     433         autoces_view as forecast_autoces_view,
#     434         autoets_model as forecast_autoets_model,
#     435         autoets_view as forecast_autoets_view,
#     436         autoselect_model as forecast_autoselect_model,
#     437         autoselect_view as forecast_autoselect_view,
#     438         brnn_model as forecast_brnn_model,
#     439         brnn_view as forecast_brnn_view,
#     440         expo_model as forecast_expo_model,
#     441         expo_view as forecast_expo_view,
#     442         forecast_model,
#     443         forecast_view,
#     444         linregr_model as forecast_linregr_model,
#     445         linregr_view as forecast_linregr_view,
#     446         mstl_model as forecast_mstl_model,
#     447         mstl_view as forecast_mstl_view,
#     448         nbeats_model as forecast_nbeats_model,
#     449         nbeats_view as forecast_nbeats_view,
#     450         nhits_model as forecast_nhits_model,
#     451         nhits_view as forecast_nhits_view,
#     452         regr_model as forecast_regr_model,
#     453         regr_view as forecast_regr_view,
#     454         rnn_model as forecast_rnn_model,
#     455         rnn_view as forecast_rnn_view,
#     456         rwd_model as forecast_rwd_model,
#     457         rwd_view as forecast_rwd_view,
#     458         seasonalnaive_model as forecast_seasonalnaive_model,
#     459         seasonalnaive_view as forecast_seasonalnaive_view,
#     460         tcn_model as forecast_tcn_model,
#     461         tcn_view as forecast_tcn_view,
#     462         tft_model as forecast_tft_model,
#     463         tft_view as forecast_tft_view,
#     464         theta_model as forecast_theta_model,
#     465         theta_view as forecast_theta_view,
#     466         trans_model as forecast_trans_model,
#     467         trans_view as forecast_trans_view,
#     468         whisper_model as forecast_whisper_model,
#     469     )
#     470 except ImportError:
#     471     FORECASTING_TOOLKIT_ENABLED = False
#
# File /usr/local/lib/python3.9/dist-packages/openbb_terminal/forecast/anom_model.py:13
#      10 from darts.ad import KMeansScorer, QuantileDetector
#      12 from openbb_terminal.decorators import log_start_end
# ---> 13 from openbb_terminal.forecast import helpers
#      15 logger = logging.getLogger(__name__)
#      18 @log_start_end(log=logger)
#      19 def get_anomaly_detection_data(
#      20     data: Union[pd.Series, pd.DataFrame],
#      21     target_column: str = "close",
#      22     train_split: float = 0.6,
#      23 ) -> Tuple[List[TimeSeries], List[TimeSeries], List[TimeSeries]]:
#
# File /usr/local/lib/python3.9/dist-packages/openbb_terminal/forecast/helpers.py:15
#      13 from darts.explainability.shap_explainer import ShapExplainer
#      14 from darts.metrics import mape, mse, rmse, smape
# ---> 15 from darts.models.forecasting.torch_forecasting_model import GlobalForecastingModel
#      16 from darts.utils.statistics import plot_residuals_analysis
#      17 from pytorch_lightning.callbacks.early_stopping import EarlyStopping
#
# File /usr/local/lib/python3.9/dist-packages/darts/models/forecasting/torch_forecasting_model.py:31
#      29 import numpy as np
#      30 import pandas as pd
# ---> 31 import pytorch_lightning as pl
#      32 import torch
#      33 from pytorch_lightning import loggers as pl_loggers
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/__init__.py:30
#      27     _logger.addHandler(logging.StreamHandler())
#      28     _logger.propagate = False
# ---> 30 from pytorch_lightning.callbacks import Callback  # noqa: E402
#      31 from pytorch_lightning.core import LightningDataModule, LightningModule  # noqa: E402
#      32 from pytorch_lightning.trainer import Trainer  # noqa: E402
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/callbacks/__init__.py:14
#       1 # Copyright The PyTorch Lightning team.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      12 # See the License for the specific language governing permissions and
#      13 # limitations under the License.
# ---> 14 from pytorch_lightning.callbacks.base import Callback
#      15 from pytorch_lightning.callbacks.device_stats_monitor import DeviceStatsMonitor
#      16 from pytorch_lightning.callbacks.early_stopping import EarlyStopping
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/callbacks/base.py:25
#      22 from torch.optim import Optimizer
#      24 import pytorch_lightning as pl
# ---> 25 from pytorch_lightning.utilities.types import STEP_OUTPUT
#      28 class Callback:
#      29     r"""
#      30     Abstract base class used to build new callbacks.
#      31
#      32     Subclass this class and override any of the relevant hooks
#      33     """
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/__init__.py:18
#      14 """General utilities."""
#      16 import numpy
# ---> 18 from pytorch_lightning.utilities.apply_func import move_data_to_device  # noqa: F401
#      19 from pytorch_lightning.utilities.distributed import AllGatherGrad  # noqa: F401
#      20 from pytorch_lightning.utilities.enums import (  # noqa: F401
#      21     _AcceleratorType,
#      22     _StrategyType,
#    (...)
#      27     ModelSummaryMode,
#      28 )
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/apply_func.py:29
#      26 import torch
#      28 from pytorch_lightning.utilities.exceptions import MisconfigurationException
# ---> 29 from pytorch_lightning.utilities.imports import _compare_version, _TORCHTEXT_LEGACY
#      30 from pytorch_lightning.utilities.warnings import rank_zero_deprecation
#      32 if _TORCHTEXT_LEGACY:
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/imports.py:118
#     116 _TORCH_QUANTIZE_AVAILABLE = bool([eg for eg in torch.backends.quantized.supported_engines if eg != "none"])
#     117 _TORCHTEXT_AVAILABLE = _package_available("torchtext")
# --> 118 _TORCHTEXT_LEGACY: bool = _TORCHTEXT_AVAILABLE and _compare_version("torchtext", operator.lt, "0.11.0")
#     119 _TORCHVISION_AVAILABLE = _package_available("torchvision")
#     120 _WANDB_AVAILABLE = _package_available("wandb")
#
# File /usr/local/lib/python3.9/dist-packages/pytorch_lightning/utilities/imports.py:71, in _compare_version(package, op, version, use_base_version)
#      63 """Compare package version with some requirements.
#      64
#      65 >>> _compare_version("torch", operator.ge, "0.1")
#    (...)
#      68 False
#      69 """
#      70 try:
# ---> 71     pkg = importlib.import_module(package)
#      72 except (ImportError, DistributionNotFound):
#      73     return False
#
# File /usr/lib/python3.9/importlib/__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# --> 127 return _bootstrap._gcd_import(name[level:], package, level)
#
# File /usr/local/lib/python3.9/dist-packages/torchtext/__init__.py:6
#       3 from torch.hub import _get_torch_home
#       5 # the following import has to happen first in order to load the torchtext C++ library
# ----> 6 from torchtext import _extension  # noqa: F401
#       8 _TEXT_BUCKET = "https://download.pytorch.org/models/text/"
#      10 _CACHE_DIR = os.path.expanduser(os.path.join(_get_torch_home(), "text"))
#
# File /usr/local/lib/python3.9/dist-packages/torchtext/_extension.py:64
#      59     # This import is for initializing the methods registered via PyBind11
#      60     # This has to happen after the base library is loaded
#      61     from torchtext import _torchtext  # noqa
# ---> 64 _init_extension()
#
# File /usr/local/lib/python3.9/dist-packages/torchtext/_extension.py:58, in _init_extension()
#      55 if not _mod_utils.is_module_available("torchtext._torchtext"):
#      56     raise ImportError("torchtext C++ Extension is not found.")
# ---> 58 _load_lib("libtorchtext")
#      59 # This import is for initializing the methods registered via PyBind11
#      60 # This has to happen after the base library is loaded
#      61 from torchtext import _torchtext
#
# File /usr/local/lib/python3.9/dist-packages/torchtext/_extension.py:50, in _load_lib(lib)
#      48 if not path.exists():
#      49     return False
# ---> 50 torch.ops.load_library(path)
#      51 return True
#
# File /usr/local/lib/python3.9/dist-packages/torch/_ops.py:220, in _Ops.load_library(self, path)
#     215 path = torch._utils_internal.resolve_library_path(path)
#     216 with dl_open_guard():
#     217     # Import the shared library into the process, thus running its
#     218     # static (global) initialization code in order to register custom
#     219     # operators with the JIT.
# --> 220     ctypes.CDLL(path)
#     221 self.loaded_libraries.add(path)
#
# File /usr/lib/python3.9/ctypes/__init__.py:374, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     371 self._FuncPtr = _FuncPtr
#     373 if handle is None:
# --> 374     self._handle = _dlopen(self._name, mode)
#     375 else:
#     376     self._handle = handle
#
# OSError: /usr/local/lib/python3.9/dist-packages/torchtext/lib/libtorchtext.so: undefined symbol: _ZN2at4_ops5zeros4callEN3c108ArrayRefINS2_6SymIntEEENS2_8optionalINS2_10ScalarTypeEEENS6_INS2_6LayoutEEENS6_INS2_6DeviceEEENS6_IbEE
